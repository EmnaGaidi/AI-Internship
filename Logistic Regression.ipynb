# %%
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.datasets import make_classification 
from sklearn.linear_model import SGDClassifier

# %%
# Génération de données aléatoires: 100 exemples, 2 classes, 2 features x0 et x1 
np.random.seed(1) 
x, y = make_classification(n_samples=100,n_features=2, n_redundant=0, n_informative=1, n_clusters_per_class=1)

# %%
# Visualisation des données 
plt.figure(num=None, figsize=(8, 6)) 
#  Cette ligne de code crée un nuage de points (scatter plot) dans la figure. Les données pour le nuage de points sont fournies sous la forme de deux colonnes de la matrice x. La première colonne x[:, 0] est utilisée comme coordonnée x et la deuxième colonne x[:, 1] comme coordonnée y. Le paramètre marker spécifie le marqueur à utiliser pour chaque point (dans ce cas, un cercle 'o'). Le paramètre c spécifie la couleur des points en fonction des valeurs dans le tableau y. Chaque valeur de y détermine la couleur du point correspondant. Enfin, le paramètre edgecolors spécifie la couleur des bords des points, dans ce cas, 'k' signifie noir.
plt.scatter(x[:,0], x[:, 1], marker = 'o', c=y, edgecolors='k')
plt.xlabel('X0') 
plt.ylabel('X1') 
x.shape
# Out:
# (100, 2)

# %%
# Génération d'un modele en utilisant la fonction cout 'log' pour Logistic Regression 
model = SGDClassifier(max_iter=1000, eta0=0.001, loss='log_loss') 
model.fit(X, y) 
print('score:', model.score(x, y))
# Out:
# score: 1.0

# %%
# Visualisation des données 
h = .02 
#Cette ligne définit une chaîne de caractères contenant les couleurs à utiliser pour les différentes classes. Dans cet exemple, les classes sont représentées par les lettres "b" (bleu), "r" (rouge), et "y" (jaune).
colors = "bry" 
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1 
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1 
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
#  Cette ligne utilise le modèle model pour prédire les classes pour chaque point de la grille.
Z = model.predict(np.c_[xx.ravel(), yy.ravel()]) 
Z = Z.reshape(xx.shape) 
cs = plt.contourf(xx, yy, Z, cmap=plt.cm.Paired) 
plt.axis('tight') 
for i, color in zip(model.classes_, colors): 
    idx = np.where(y == i) 
    plt.scatter(X[idx, 0], X[idx, 1], c=color, cmap=plt.cm.Paired, edgecolor='black', s=20)
# Out:
# C:\Users\emnag\AppData\Local\Temp\ipykernel_40940\2644310627.py:14: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, cmap=plt.cm.Paired, edgecolor='black', s=20)
