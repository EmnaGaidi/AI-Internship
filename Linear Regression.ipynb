# %%
import numpy as np 
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# # Degré 1

# %%
# make_regression nous permet de générer des données
np.random.seed(0)
x,y = make_regression(n_samples=100,n_features=1,noise = 10)
plt.scatter(x,y)

# %%
model = SGDRegressor(max_iter = 1000,eta0=0.001)
model.fit(x,y)
# Out:
# SGDRegressor(eta0=0.001)

# %%
print('Coeff R2 =', model.score(x, y)) 
plt.scatter(x, y) 
plt.plot(x, model.predict(x), c='red', lw = 3)
# Out:
# Coeff R2 = 0.941656539437565

# %% [markdown]
# # Degré 2

# %%
np.random.seed(0) 
# création du Dataset 
x, y = make_regression(n_samples=100, n_features=1, noise=10) 
y = y**2 # y ne varie plus linéairement selon x ! 
# y = y**2 : Cette ligne élève au carré toutes les valeurs de la variable cible y.
#Cela a pour effet de rendre la relation entre x et y non linéaire, car y est maintenant fonction de x à la puissance 2.
# On ajoute des variables polynômiales dans notre dataset 
poly_features = PolynomialFeatures(degree=2, include_bias=False) 
x = poly_features.fit_transform(x) 
plt.scatter(x[:,0], y) 
x.shape # la dimension de x: 100 lignes et 2 colonnes
# Out:
# (100, 2)

# %%
# On entraine le modele comme avant ! rien ne change ! 
model = SGDRegressor(max_iter=1000, eta0=0.001) 
model.fit(x,y) 
print('Coeff R2 =', model.score(x, y)) 
plt.scatter(x[:,0], y, marker='o') 
plt.scatter(x[:,0], model.predict(x), c='red', marker='+')
# Out:
# Coeff R2 = 0.8940618874083447
# C:\Users\emnag\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1548: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
